# %% [markdown]
# **1. Import The Libraries And Dataset**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/heart.csv")

# %% [markdown]
# **2.Display Top 5 Rows**

# %%
data.head()

# %% [markdown]
# **3.Check the Last 5 Rows of the Dataset**

# %%
data.tail()

# %% [markdown]
# **4. Find Shape of Our Dataset (Number of Rows And Number of Columns)**

# %%
data.shape

# %%
print("Number of Rows: ",data.shape[0])
print("Number of Columns: ",data.shape)

# %% [markdown]
# **5. Get Information About Our Dataset Like Total Number Rows,Total Number of Columns, Datatypes of Each Column And Memory Requirement**

# %%
data.info()

# %% [markdown]
# **6. Check Null Values In The Dataset**

# %%
data.isnull().sum()

# %% [markdown]
# **7. Check For Duplicate Data and Drop Them**

# %%
data_dup = data.duplicated().any()
print(data_dup)

# %%
data.shape

# %%
data = data.drop_duplicates()

# %%
data_dup = data.duplicated().any()
print(data_dup)

# %%
data.shape

# %% [markdown]
# **8. Get Overall Statistcs About The Dataset**

# %%
data.describe()

# %% [markdown]
# **9.Draw Correlation Matrix**

# %%
plt.figure(figsize=(17,6))
sns.heatmap(data.corr(),annot=True)

# %% [markdown]
# **10.How Many People Have Heart Disease,And How Many Don't Have Heart Disease in the Dataset?**

# %%
data.columns

# %%
data['target'].value_counts()

# %%
data['target'] = data['target'].astype(int)
sns.countplot(x=data['target'])

# %%
print(data.head())
print(data.columns)

# %% [markdown]
# **11. Find the Count of Male And Female in this Dataset**

# %%
data.columns

# %%
data['sex'].value_counts()

# %%
data['sex'] = data['sex'].astype(int)
sns.countplot(x=data['sex'])
plt.xticks([0,1],['Female','Male'])
plt.show()

# %% [markdown]
# **12. Find Gender Distribution According to The Target**

# %%
data.columns

# %%
sns.countplot(x='sex',hue='target',data = data)
plt.xticks([0,1],['Female','Male'])
plt.legend(labels=['No-Disease','Disease'])
plt.show()

# %% [markdown]
# **13.Check Age Distribution In the Dataset**

# %%
sns.displot(data['age'],bins=20)
plt.show()

# %% [markdown]
# 14. Check Chest Pain Type
# Chest pain type (4 values)
#
# Value 0: typical angina
#
# Value 1: atypical angina
#
# Value 2: non-anginal pain
#
# Value 3: asymptomatic

# %%
data['cp'] = data['cp'].astype(int)
sns.countplot(x=data['cp'])
plt.xticks([0,1,2,3],["typical angina","atypical angina","non-anginal pain","asymptomatic"])
plt.show()

# %% [markdown]
# **15. Show The Chest Pain Distribution As Per Target Variable**

# %%
data.columns

# %%
sns.countplot(x="cp",hue="target",data=data)
plt.legend(labels=['No-Disease','Disease'])
plt.show()

# %% [markdown]
# **16. Show Fasting Blood Sugar Distribution According To Target Variable**

# %%
sns.countplot(x="fbs",hue="target",data=data)
plt.legend(labels=['No-Disease','Disease'])
plt.show()

# %% [markdown]
# **17. Check Resting Blood Pressure Distribution**

# %%
data['trestbps'].hist()

# %% [markdown]
# **18. Compare Resting Blood Presuure As Per Sex Column**

# %%
sns.kdeplot(data=data, x="trestbps", hue="sex", fill=True)

# %% [markdown]
# **19. Show Distribution Of Serum Cholestrol**

# %%
data['chol'].hist()

# %% [markdown]
# **20. Plot Continuous Variables**

# %%
cate_val=[]
cont_val=[]
for column in data.columns:
  if data[column].nunique()<=10:
    cate_val.append(column)
  else:
    cont_val.append(column)

# %%
cate_val

# %%
cont_val

# %%
data.hist(cont_val,figsize=(15,6))
plt.show()
